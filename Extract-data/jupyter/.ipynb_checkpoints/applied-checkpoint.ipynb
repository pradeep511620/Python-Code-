# %%
import concurrent.futures
import time
from urllib.parse import urljoin
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import undetected_chromedriver as uc
from selenium.webdriver.chrome.options import Options
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"}

chrome_options = Options()
chrome_options.add_argument("--no-sandbox")
# chrome_options.add_argument('--headless')
chrome_options.add_argument(f'user-agent={headers["User-Agent"]}')
driver = webdriver.Chrome(options=chrome_options)
driver.maximize_window()
# url = 'https://www.onlinecomponents.com/en/productdetail/cutler-hammer--eaton/xtpext032b-56196481.html'
url = 'https://www.allvalves.co.uk/actuator-valves/knife-gate-valve-bi-directional-pneumatic-actuated-tecofi'
driver.get(url)
time.sleep(5)
page_sources = driver.page_source
pk = BeautifulSoup(page_sources, 'lxml')

# %%
pk.prettify()
# Out:
# '<html class="cufon-active cufon-ready" xmlns="http://www.w3.org/1999/xhtml">\n <head>\n  <!-- lead forensics \n    <script type="text/javascript" src="https://ult-blk-cbl.com/js/34141.js" ></script>\n    <noscript><img src="https://ult-blk-cbl.com/images/track/34141.png?trk_user=34141&trk_tit=jsdisabled&trk_ref=jsdisabled&trk_loc=jsdisabled" height="0px" width="0px" style="display:none;" /></noscript>\n-->\n  <title>\n   Knife Gate Valve Bi Directional Pneumatic Actuated Tecofi\n  </title>\n  <!-- Google Tag Manager -->\n  <script async="" nonce="null" src="//www.gstatic.com/call-tracking/call-tracking_9.js">\n  </script>\n  <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-L702V0ZK1G&amp;cx=c&amp;_slc=1" type="text/javascript">\n  </script>\n  <script async="" src="https://www.gstatic.com/wcm/loader.js" type="text/javascript">\n  </script>\n  <script id="twitter-wjs" src="https://platform.twitter.com/widgets.js">\n  </script>\n  <script async="" src="https://www.google-analytics.com/analytics.js">\n  </script>\n  <script async="" src="https://www.googletagmanager.com/gtm.js?id=GTM-5CXGPH2">\n  </script>\n  <script>\n   (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n    new Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n    j=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n    \'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n    })(window,document,\'script\',\'dataLayer\',\'GTM-5CXGPH2\');\n  </script>\n  <!-- End Google Tag Manager -->\n  <meta content="width=device-width,initial-scale=1.0" name="viewport"/>\n  <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon"/>\n  <link href="/favicon.ico" rel="icon" type="image/x-icon"/>\n  <link href="/images/favicon/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>\n  <link href="/images/favicon/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>\n  <link href="/images/favicon/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>\n  <link href="/images/favicon/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>\n  <link href="/images/favicon/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>\n  <link href="/images/favicon/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>\n  <link href="/images/favicon/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>\n  <link href="/images/favicon/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>\n  <link href="/images/favicon/apple-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>\n  <link href="/images/favicon/android-icon-192x192.png" rel="icon" sizes="192x192" type="image/png"/>\n  <link href="/images/favicon/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>\n  <link href="/images/favicon/favicon-96x96.png" rel="icon" sizes="96x96" type="image/png"/>\n  <link href="/images/favicon/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>\n  <link href="/manifest.json" rel="manifest"/>\n  <meta content="#ffffff" name="msapplication-TileColor"/>\n  <meta content="/ms-icon-144x144.png" name="msapplication-TileImage"/>\n  <meta content="#ffffff" name="theme-color"/>\n  <link href="/css/stylesheet.css" rel="stylesheet" type="text/css"/>\n  <link href="/css/jquery.autocomplete.css" rel="stylesheet" type="text/css"/>\n  <!-- jQuery -->\n  <link href="//code.jquery.com/ui/1.12.1/themes/smoothness/jquery-ui.css" rel="stylesheet"/>\n  <script src="//code.jquery.com/jquery-1.12.4.js">\n  </script>\n  <script src="//code.jquery.com/ui/1.12.1/jquery-ui.js">\n  </script>\n  <!-- slimbox -->\n  <script src="/js/slimbox2/slimbox2.js" type="text/javascript">\n  </script>\n  <link href="/js/slimbox2/slimbox2.css" media="screen" rel="stylesheet" type="text/css"/>\n  <!-- metadata -->\n  <meta content="global" name="distribution"/>\n  <meta content="general" name="rating"/>\n  <meta content="2019" name="copyright" ...

# %% [markdown]
# # L3_Name

# %%
names = [l3.text.strip() for l3 in pk.select("#crumbtrail a")]
l3_Name = 'Home## ' +"## ".join(names)
print('l3_Name.....', l3_Name)
# Out:
# l3_Name..... Home## MANUAL VALVES## Knife Gate Valves## Knife Gate Valve Bi Directional Pneumatic Actuated Tecofi

# %% [markdown]
# # Title

# %%
product_title = pk.select_one("#pageTitle h1").text.strip()
product_title
# Out:
# 'Knife Gate Valve Bi Directional Pneumatic Actuated Tecofi'

# %% [markdown]
# ## Mpn

# %%
try:
    mpn_number = pk.find('input', {'id': 'adp-article-number-filter'})
    mpn = mpn_number.get('value')
    print(mpn)
except AttributeError:
    print("'NoneType' object has no attribute 'get'")
# Out:
# 'NoneType' object has no attribute 'get'

# %% [markdown]
# ## short desc

# %%
try:
    short = pk.select_one("div.product .slo-product-info p.my-md").text.strip()
except AttributeError:
    print("NoneType' object has no attribute 'text")
# Out:
# NoneType' object has no attribute 'text

# %% [markdown]
# ## Description_1

# %%
description = [des.text.strip() for des in pk.select("div#content p")[2:-1]]
print(description)
# Out:
# ['Knife Gate Valves from Tecofi, a French valve manufacturer specialising in valves for Water Treatment, Biogas and General Industrial Process.', '', 'The Series 43022 is a Bi Directional cast iron knife gate valve, with NBR seal with a stainless steel gate, suitable for fitting between PN10 flanges and operated by a hand wheel operator. Available from DN50 to DN400 and deliveries for non stock items usually 7-10 days from date of order.', 'Suitable for use on WWT applications, Biogas, Slurry and other Industrial Process applications.', "Don't forget your accessories, we can supply a wide range of accessories including limit switches, flanges and gaskets.", 'To buy a priced product online, please click on it in the table below.Full pricing, discounts, datasheets and extended information will also be available on that page.If you would like bulk or project pricing, technical support, or have any other inquiries, please use the RFQ or call buttons to discuss your requirements with a member of our team.', 'General Note:']

# %% [markdown]
# ## Description_2

# %%
description_2 = [feature.text.strip() for feature in pk.select("section.product-section.product-features-list ul li")]
if not description_2:
    description_2 = ['No Feature available ']
description_2
# Out:
# ['No Feature available ']

# %% [markdown]
# ## Price

# %%
pr_qty = ''
try:
    pr_qty = pk.select_one("div.prodData .umDiv").text.strip().split(':')[1].strip()
except (AttributeError, TypeError, IndexError, Exception) as e:
    print(f"An error occurred: {e} pr_qty -----: {pr_qty}")
    
# -------------------------------------------------- Price -----------------------------------------------------
product_price = ''
try:
    product_price = pk.select_one("span[itemprop='price']").text.strip()
except (AttributeError, TypeError, IndexError, Exception) as e:
    print(f"An error occurred: {e} product_price -----: {product_price}")

price = {'list_price': '$-.--' + pr_qty, 'qty': '1', 'moq': '1'}
print(price)
# Out:
# An error occurred: 'NoneType' object has no attribute 'text' pr_qty -----:
# An error occurred: 'NoneType' object has no attribute 'text' product_price -----:
# {'list_price': '$-.--', 'qty': '1', 'moq': '1'}

# %% [markdown]
# ## description_2

# %%
try:
    description_2 = [feature.text.strip() for feature in pk.select("#spec ul li")]
    if not description_2:
        raise ValueError("No description_2 found")
    print('description_2.....', description_2)
except (AttributeError, TypeError, IndexError, Exception) as e:
    description_2 = []
    print(f"An error occurred: {e} description_2 -----: {description_2}")
# Out:
# An error occurred: No description_2 found description_2 -----: []

# %% [markdown]
# ## Images

# %%
images = [{"src": img.get('src'), "alt": img.get('alt')} for img in pk.select("div.mainProductImage img")]
print(images)
# Out:
# [{'src': '/UserControls/ThumbNailGenerator.aspx?img=/uploads/images/categories/vg3400-03-jpg&w=250&h=250&ar=true', 'alt': 'Knife Gate Valve Bi Directional Pneumatic Actuated Tecofi'}]

# %% [markdown]
# ## Specs

# %%
attri_name = []
attri_value = []
row_count = 0
for table in pk.select("section#specifications span"):
    tab = table.text.strip()
    row_count += 1
    if row_count % 2 != 0:
        attri_name.append(tab)
    else:
        attri_value.append(tab)
specs = [{name:value for name, value in zip(attri_name, attri_value)}]
print(specs)
# Out:
# [{}]

# %%
tables = pk.select("section#specifications span")
it = iter(tables)
specs = [{name.text.strip(): value.text.strip()} for name, value in zip(it, it)]
if not specs:
    specs = ['No Specs available ']
print(specs)
# Out:
# ['No Specs Available ']

# %%
try:
    Packed_per = pk.select_one("#add-to-cart-row").text.strip().replace('\n', '').split('Full')[0].replace('-+Packed per', '').strip()
    print(Packed_per)
except AttributeError:
    print("'NoneType' object has no attribute 'text'")
# Out:
# 'NoneType' object has no attribute 'text'

# %%
try:
    in_stocks = pk.select_one("div.adp-stock span").text.strip()
    print(in_stocks)
except AttributeError:
    print("'NoneType' object has no attribute 'text'")
# Out:
# 'NoneType' object has no attribute 'text'

# %% [markdown]
# ## Logo

# %%
logo = pk.select_one("div#content p img").get('src')
print(logo)
# Out:
# https://www.allvalves.co.uk/uploads/images/2019%20Website%20Images/Logos/Tecofi_logo.jpg

# %% [markdown]
# ## Datasheet

# %%
datasheet = [pdf.get('href') for pdf in pk.select("#downloads a") if pdf.get('href') and 'pdf' in pdf.get('href').lower()]
if not datasheet:
    datasheet = ['No datasheet available']
print(datasheet)
# Out:
# ['No datasheet available']

# %% [markdown]
# ## Related

# %%
source_of_related = [source.get('href') for source in pk.select('div.related-products-grid header a')]
if not source_of_related:
    source_of_related = ['No related url available']
print(source_of_related)
# Out:
# ['No related url available']

# %% [markdown]
# ## Miscellaneous

# %%
notes = pk.select("div#content p")[-1].text.strip()
notes
# Out:
# "Please place your order by selecting the product listed above, this will show any discounts available whilst also showing you additional information including technical specifications and datasheets. From this screen you can add to basket also. Note that some products will be box quantities, this should be clearly shown on screen. If there is no box quantities stated, then all items are individually listed and priced. If the item you are interested is not showing as 'In Stock', please do contact us to check the best availability or allow us to offer an alternative/ like for like product. Products showing as '2-3 Days' might actually be available next day, please check with us before leaving the site. Goods showing as factory lead time or '7-10 Days' are typically from our European stocks and can often be made available on a shorter lead time for urgent requirements."

# %%
text = ""
for element in pk.find_all(['font', 'img']):
    print(element)
#     if element.name == 'font':
#         text += element.get_text()  # Extract text from <font> tag
#     elif element.name == 'img':
#         text += element.get('alt')  # Extract alt attribute from <img> tag
#     if element.next_sibling and isinstance(element.next_sibling, str):
#         text += element.next_sibling.strip()  # Get any text next to the element

# # Print the combined text
# print(text)
# Out:
# <img border="0" src="/images/shell/allvalves_original.png"/>
# <img alt="Knife Gate Valve Bi Directional Pneumatic Actuated Tecofi" border="0" src="/UserControls/ThumbNailGenerator.aspx?img=/uploads/images/categories/vg3400-03-jpg&amp;w=250&amp;h=250&amp;ar=true"/>
# <img alt="" src="https://www.allvalves.co.uk/uploads/images/2019%20Website%20Images/Logos/Tecofi_logo.jpg" style="left: 729px; top: 205px; width: 304px; height: 110px;"/>
# <font size="3"><strong>Stock: </strong></font>
# <img alt="Stock available next day" class="status-led" src="/images/green-dot.png"/>
# <img alt="Stock available next day" class="status-led" src="/images/orange-dot.png"/>
# <img alt="Stock available next day" class="status-led" src="/images/red-dot.png"/>
# <img alt="All Valves Online - Always Online!" src="/uploads/images/2019%20Website%20Images/Logos/allvalves-logo-round-small.png" style="width: 50px; height: 50px;"/>
# <font size="7"><span style="color: rgb(43, 121, 190);">The Valve Actuation Specialists</span></font>
# <img alt="AllValves Twitter Feed" border="0" src="/images/twitter-logo.jpg"/>
# <img alt="We accept Visa, Mastercard, Maestro, Solo and PayPal" border="0" src="/images/payment-icons-payment-page.png"/>
# <img alt="Secured by SagePay" border="0" src="/images/securedbysagepayv3-1.jpg"/>
# <img alt="SSL Secure" border="0" src="/images/Website-Security-101_1.png"/>
# <img border="0" src="/images/live-chat-banner.png"/>
# <img border="0" src="/images/TNT_Van_medium.png"/>
# <img border="0" src="/images/cta-same-day-dispatch-2pm.png"/>
# <img alt="Fast, same day shipping" border="0" src="/images/super-fast-shipping.png"/>
# <img alt="Visit us on Facebook.com" src="/images/social-icons/facebook-white-icon.png"/>
# <img alt="Visit us on Twitter.com" src="/images/social-icons/twitter-white-icon.png"/>
# <img alt="Visit us on YouTube.com" src="/images/social-icons/youtube-white-icon.png"/>
